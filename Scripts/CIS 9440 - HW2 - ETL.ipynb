# %%
# Microoft Azure
# !pip install azure-storage-blob
# !pip install pyarrow
# !pip install psycopg2 sqlalchemy
# Out:
# Requirement already satisfied: azure-storage-blob in c:\users\jrami\anaconda3\lib\site-packages (12.19.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in c:\users\jrami\anaconda3\lib\site-packages (from azure-storage-blob) (1.30.1)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\jrami\anaconda3\lib\site-packages (from azure-storage-blob) (42.0.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\jrami\appdata\roaming\python\python311\site-packages (from azure-storage-blob) (4.11.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\jrami\anaconda3\lib\site-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\jrami\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\jrami\appdata\roaming\python\python311\site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jrami\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\jrami\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jrami\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jrami\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jrami\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jrami\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Requirement already satisfied: pyarrow in c:\users\jrami\anaconda3\lib\site-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\jrami\anaconda3\lib\site-packages (from pyarrow) (1.26.4)
# Requirement already satisfied: psycopg2 in c:\users\jrami\anaconda3\lib\site-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in c:\users\jrami\anaconda3\lib\site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jrami\appdata\roaming\python\python311\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jrami\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from math import ceil
import datetime
import calendar
from sqlalchemy import create_engine

# %%
# Azure Functions
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# Google Cloud Functions
def google_upload_blob(bucket_name, source_file_name, destination_blob_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)
    print(f"File {source_file_name} uploaded to {destination_blob_name}.")

def google_download_blob(bucket_name, source_blob_name, destination_file_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    blob.download_to_filename(destination_file_name)
    print(f"Blob {source_blob_name} downloaded to {destination_file_name}.")

# AWS Functions
def aws_upload_file(file_name, bucket, object_name=None):
    if object_name is None:
        object_name = os.path.basename(file_name)
    s3_client = boto3.client('s3')
    response = s3_client.upload_file(file_name, bucket, object_name)
    print(f"Uploaded {file_name} to S3 bucket {bucket}.")

def aws_download_file(bucket, object_name, file_name):
    s3_client = boto3.client('s3')
    s3_client.download_file(bucket, object_name, file_name)
    print(f"Downloaded {object_name} from S3 bucket {bucket}.")

# %%
def week_of_month(dt):
    first_day = dt.replace(day=1)
    dom = dt.day
    adjusted_dom = dom + first_day.weekday()
    return int(ceil(adjusted_dom/7.0))

def get_week_of_year(date_str):
    """
    Calculate the ISO week number of the year for a given date.

    Parameters:
    date_str (str): A date string in the format 'YYYY-MM-DD'.

    Returns:
    int: ISO week number of the year.
    """
    # Parse the input string to a datetime object
    date = datetime.strptime(date_str, '%Y-%m-%d')

    # Get the ISO calendar week number
    week_of_year = date.isocalendar()[1]

    return week_of_year

# %%
# Specify the path to your JSON configuration file
config_file_path = 'config.json'

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

# Print the configuration
#Connection_STRING = config["connectionString"]

CONNECTION_STRING_AZURE_STORAGE = config['connectionString']
CONTAINER_AZURE = 'nypdcomplaints'

# Initialize the BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get the container client
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)


nypd_complaints_df = pd.DataFrame()

# List all blobs in the specified container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print(blob.name)
    blob_client = container_client.get_blob_client(blob=blob.name)
    blob_data = blob_client.download_blob()
    blob_content = blob_data.readall().decode('utf-8')
    df = pd.read_csv(StringIO(blob_content))
    # Display the head of the DataFrame
    print(df.shape)
    # since I have only one csv, I am doing to do the following instructions
    nypd_complaints_df = df.copy()
# Out:
# NYPD_COMPLAINTS_CLEAN.csv
# (555117, 21)

# %%
nypd_complaints_df.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'JURIS_DESC',
#        'KY_CD', 'LAW_CAT_CD', 'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'X_COORD_CD', 'Y_COORD_CD',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
nypd_complaints_df.head()
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0    269235387         42.0     BRONX     6/3/2023      1:00:00   12/31/2023
# 1    262102261         43.0     BRONX    1/18/2023     14:00:00   12/31/2023
# 2    267972239         43.0     BRONX     5/7/2023      0:15:00   12/31/2023
# 3  263141402H1          0.0  BROOKLYN     2/6/2023     10:16:00   12/31/2023
# 4  269307857H1          0.0  BROOKLYN     6/4/2023      0:20:00   12/31/2023
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  ...  \
# 0     23:59:59        COMPLETED  N.Y. POLICE DEPT    105  ...
# 1     23:59:59        COMPLETED  N.Y. POLICE DEPT    113  ...
# 2     23:59:59        COMPLETED  N.Y. POLICE DEPT    106  ...
# 3     23:59:59        COMPLETED  N.Y. POLICE DEPT    101  ...
# 4     23:59:59        COMPLETED  N.Y. POLICE DEPT    101  ...
#
#   LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0      NOT REPORTED                          ROBBERY  366.0
# 1      NOT REPORTED                          FORGERY  725.0
# 2          FRONT OF                   FELONY ASSAULT  105.0
# 3           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER    0.0
# 4           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER    0.0
#
#                      PD_DESC            PREM_TYP_DESC     RPT_DT X_COORD_CD  \
# 0            ROBBERY,BICYCLE                   STREET   6/3/2023  1011982.0
# 1  FORGERY,M.V. REGISTRATION                   STREET  1/18/2023  1019635.0
# 2          STRANGULATION 1ST                   STREET   5/9/2023  1022051.0
# 3               NOT REPORTED  MULTI DWELL - APT BUILD   2/6/2023        0.0
# 4               NOT REPORTED             NOT REPORTED   6/4/2023        0.0
#
#    Y_COORD_CD   Latitude  Longitude
# 0    239520.0  40.824059 -73.899799
# 1    243829.0  40.835859 -73.872125
# 2    242244.0  40.831500 -73.863400
# 3         0.0   0.000000   0.000000
# 4         0.0   0.000000   0.000000
#
# [5 rows x 21 columns]

# %%
nypd_complaints_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555117 entries, 0 to 555116
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         555117 non-null  object
#  1   ADDR_PCT_CD        555117 non-null  float64
#  2   BORO_NM            555117 non-null  object
#  3   CMPLNT_FR_DT       555117 non-null  object
#  4   CMPLNT_FR_TM       555117 non-null  object
#  5   CMPLNT_TO_DT       555117 non-null  object
#  6   CMPLNT_TO_TM       555117 non-null  object
#  7   CRM_ATPT_CPTD_CD   555117 non-null  object
#  8   JURIS_DESC         555117 non-null  object
#  9   KY_CD              555117 non-null  int64
#  10  LAW_CAT_CD         555117 non-null  object
#  11  LOC_OF_OCCUR_DESC  555117 non-null  object
#  12  OFNS_DESC          555117 non-null  object
#  13  PD_CD              555117 non-null  float64
#  14  PD_DESC            555117 non-null  object
#  15  PREM_TYP_DESC      555117 non-null  object
#  16  RPT_DT             555117 non-null  object
#  17  X_COORD_CD         555117 non-null  float64
#  18  Y_COORD_CD         555117 non-null  float64
#  19  Latitude           555117 non-null  float64
#  20  Longitude          555117 non-null  float64
# dtypes: float64(6), int64(1), object(14)
# memory usage: 88.9+ MB

# %%
nypd_complaints_df['ADDR_PCT_CD'] = nypd_complaints_df['ADDR_PCT_CD'].astype('Int64')

# %%
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0         269235387           42     BRONX     6/3/2023      1:00:00
# 1         262102261           43     BRONX    1/18/2023     14:00:00
# 2         267972239           43     BRONX     5/7/2023      0:15:00
# 3       263141402H1            0  BROOKLYN     2/6/2023     10:16:00
# 4       269307857H1            0  BROOKLYN     6/4/2023      0:20:00
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   12/12/2023     21:00:00
# 555113    274543137          105    QUEENS    9/16/2023     12:20:00
# 555114    272734727          105    QUEENS    7/15/2023     10:50:00
# 555115    270806588          105    QUEENS     7/4/2023     21:00:00
# 555116    263569764          105    QUEENS    2/11/2023     20:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  \
# 0        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    105
# 1        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    113
# 2        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    106
# 3        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# 4        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# ...             ...          ...              ...               ...    ...
# 555112   12/12/2023     21:12:00        COMPLETED  N.Y. POLICE DEPT    361
# 555113    9/16/2023     12:25:00        COMPLETED  N.Y. POLICE DEPT    344
# 555114    7/15/2023     11:00:00        COMPLETED  N.Y. POLICE DEPT    112
# 555115     7/4/2023     21:15:00        COMPLETED  N.Y. POLICE DEPT    126
# 555116    2/14/2023      5:45:00        COMPLETED  N.Y. POLICE DEPT    341
#
#         ... LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0       ...      NOT REPORTED                          ROBBERY  366.0
# 1       ...      NOT REPORTED                          FORGERY  725.0
# 2       ...          FRONT OF                   FELONY ASSAULT  105.0
# 3       ...           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER    0.0
# 4       ...           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER    0.0
# ...     ...               ...                              ...    ...
# 555112  ...            INSIDE    OFF. AGNST PUB ORD SENSBLTY &  639.0
# 555113  ...            INSIDE     ASSAULT 3 & RELATED OFFENSES  101.0
# 555114  ...            INSIDE                      THEFT-FRAUD  739.0
# 555115  ...      NOT REPORTED          MISCELLANEOUS PENAL LAW  117.0
# 555116  ...          FRONT OF                    PETIT LARCENY  357.0
#
#                                PD_DESC            PREM_TYP_DESC      RPT_DT  \
# 0                      ROBBERY,BICYCLE                   STREET    6/3/2023
# 1            FORGERY,M.V. REGISTRATION                   STREET   1/18/2023
# 2                    STRANGULATION 1ST                   STREET    5/9/2023
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD    2/6/2023
# 4                         NOT REPORTED             NOT REPORTED    6/4/2023
# ...                                ...                      ...         ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE  12/12/2023
# 555113                       ASSAULT 3          RESIDENCE-HOUSE   9/16/2023
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED   8/10/2023
# 555115         RECKLESS ENDANGERMENT 1                   STREET    7/4/2023
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET   2/12/2023
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude
# 0       1011982.0    239520.0  40.824059 -73.899799
# 1       1019635.0    243829.0  40.835859 -73.872125
# 2       1022051.0    242244.0  40.831500 -73.863400
# 3             0.0         0.0   0.000000   0.000000
# 4             0.0         0.0   0.000000   0.000000
# ...           ...         ...        ...        ...
# 555112  1057934.0    198975.0  40.712511 -73.734210
# 555113  1064159.0    204907.0  40.728739 -73.711686
# 555114  1062587.0    206274.0  40.732507 -73.717340
# 555115  1059585.0    198510.0  40.711220 -73.728262
# 555116  1058442.0    198679.0  40.711695 -73.732383
#
# [555117 rows x 21 columns]

# %%
nypd_complaints_df['KY_CD'] = nypd_complaints_df['KY_CD'].astype('Int64')
nypd_complaints_df['PD_CD'] = nypd_complaints_df['PD_CD'].astype('Int64')
nypd_complaints_df.drop(columns=['X_COORD_CD', 'Y_COORD_CD'], inplace=True)
nypd_complaints_df.head()
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0    269235387           42     BRONX     6/3/2023      1:00:00   12/31/2023
# 1    262102261           43     BRONX    1/18/2023     14:00:00   12/31/2023
# 2    267972239           43     BRONX     5/7/2023      0:15:00   12/31/2023
# 3  263141402H1            0  BROOKLYN     2/6/2023     10:16:00   12/31/2023
# 4  269307857H1            0  BROOKLYN     6/4/2023      0:20:00   12/31/2023
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD LAW_CAT_CD  \
# 0     23:59:59        COMPLETED  N.Y. POLICE DEPT    105     FELONY
# 1     23:59:59        COMPLETED  N.Y. POLICE DEPT    113     FELONY
# 2     23:59:59        COMPLETED  N.Y. POLICE DEPT    106     FELONY
# 3     23:59:59        COMPLETED  N.Y. POLICE DEPT    101     FELONY
# 4     23:59:59        COMPLETED  N.Y. POLICE DEPT    101     FELONY
#
#   LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0      NOT REPORTED                          ROBBERY    366
# 1      NOT REPORTED                          FORGERY    725
# 2          FRONT OF                   FELONY ASSAULT    105
# 3           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# 4           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
#
#                      PD_DESC            PREM_TYP_DESC     RPT_DT   Latitude  \
# 0            ROBBERY,BICYCLE                   STREET   6/3/2023  40.824059
# 1  FORGERY,M.V. REGISTRATION                   STREET  1/18/2023  40.835859
# 2          STRANGULATION 1ST                   STREET   5/9/2023  40.831500
# 3               NOT REPORTED  MULTI DWELL - APT BUILD   2/6/2023   0.000000
# 4               NOT REPORTED             NOT REPORTED   6/4/2023   0.000000
#
#    Longitude
# 0 -73.899799
# 1 -73.872125
# 2 -73.863400
# 3   0.000000
# 4   0.000000

# %%
# Convert 'CMPLNT_FR_DT' column to datetime format with a specified format
nypd_complaints_df['CMPLNT_FR_DT'] = pd.to_datetime(nypd_complaints_df['CMPLNT_FR_DT'], format='%m/%d/%Y', errors='coerce')

# Convert datetime column to YYYY-MM-DD format
nypd_complaints_df['CMPLNT_FR_DT'] = nypd_complaints_df['CMPLNT_FR_DT'].dt.strftime('%Y-%m-%d')

# %%
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0         269235387           42     BRONX   2023-06-03      1:00:00
# 1         262102261           43     BRONX   2023-01-18     14:00:00
# 2         267972239           43     BRONX   2023-05-07      0:15:00
# 3       263141402H1            0  BROOKLYN   2023-02-06     10:16:00
# 4       269307857H1            0  BROOKLYN   2023-06-04      0:20:00
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12     21:00:00
# 555113    274543137          105    QUEENS   2023-09-16     12:20:00
# 555114    272734727          105    QUEENS   2023-07-15     10:50:00
# 555115    270806588          105    QUEENS   2023-07-04     21:00:00
# 555116    263569764          105    QUEENS   2023-02-11     20:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  \
# 0        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    105
# 1        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    113
# 2        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    106
# 3        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# 4        12/31/2023     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# ...             ...          ...              ...               ...    ...
# 555112   12/12/2023     21:12:00        COMPLETED  N.Y. POLICE DEPT    361
# 555113    9/16/2023     12:25:00        COMPLETED  N.Y. POLICE DEPT    344
# 555114    7/15/2023     11:00:00        COMPLETED  N.Y. POLICE DEPT    112
# 555115     7/4/2023     21:15:00        COMPLETED  N.Y. POLICE DEPT    126
# 555116    2/14/2023      5:45:00        COMPLETED  N.Y. POLICE DEPT    341
#
#          LAW_CAT_CD LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0            FELONY      NOT REPORTED                          ROBBERY    366
# 1            FELONY      NOT REPORTED                          FORGERY    725
# 2            FELONY          FRONT OF                   FELONY ASSAULT    105
# 3            FELONY           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# 4            FELONY           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# ...             ...               ...                              ...    ...
# 555112  MISDEMEANOR            INSIDE    OFF. AGNST PUB ORD SENSBLTY &    639
# 555113  MISDEMEANOR            INSIDE     ASSAULT 3 & RELATED OFFENSES    101
# 555114       FELONY            INSIDE                      THEFT-FRAUD    739
# 555115       FELONY      NOT REPORTED          MISCELLANEOUS PENAL LAW    117
# 555116  MISDEMEANOR          FRONT OF                    PETIT LARCENY    357
#
#                                PD_DESC            PREM_TYP_DESC      RPT_DT  \
# 0                      ROBBERY,BICYCLE                   STREET    6/3/2023
# 1            FORGERY,M.V. REGISTRATION                   STREET   1/18/2023
# 2                    STRANGULATION 1ST                   STREET    5/9/2023
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD    2/6/2023
# 4                         NOT REPORTED             NOT REPORTED    6/4/2023
# ...                                ...                      ...         ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE  12/12/2023
# 555113                       ASSAULT 3          RESIDENCE-HOUSE   9/16/2023
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED   8/10/2023
# 555115         RECKLESS ENDANGERMENT 1                   STREET    7/4/2023
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET   2/12/2023
#
#          Latitude  Longitude
# 0       40.824059 -73.899799
# 1       40.835859 -73.872125
# 2       40.831500 -73.863400
# 3        0.000000   0.000000
# 4        0.000000   0.000000
# ...           ...        ...
# 555112  40.712511 -73.734210
# 555113  40.728739 -73.711686
# 555114  40.732507 -73.717340
# 555115  40.711220 -73.728262
# 555116  40.711695 -73.732383
#
# [555117 rows x 19 columns]

# %%
# Convert 'CMPLNT_FR_DT' column to datetime format with a specified format
nypd_complaints_df['CMPLNT_TO_DT'] = pd.to_datetime(nypd_complaints_df['CMPLNT_TO_DT'], format='%m/%d/%Y', errors='coerce')
nypd_complaints_df['RPT_DT'] = pd.to_datetime(nypd_complaints_df['RPT_DT'], format='%m/%d/%Y', errors='coerce')


# Convert datetime column to YYYY-MM-DD format
nypd_complaints_df['CMPLNT_TO_DT'] = nypd_complaints_df['CMPLNT_TO_DT'].dt.strftime('%Y-%m-%d')
nypd_complaints_df['RPT_DT'] = pd.to_datetime(nypd_complaints_df['RPT_DT'], format='%m/%d/%Y', errors='coerce')

# %%
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0         269235387           42     BRONX   2023-06-03      1:00:00
# 1         262102261           43     BRONX   2023-01-18     14:00:00
# 2         267972239           43     BRONX   2023-05-07      0:15:00
# 3       263141402H1            0  BROOKLYN   2023-02-06     10:16:00
# 4       269307857H1            0  BROOKLYN   2023-06-04      0:20:00
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12     21:00:00
# 555113    274543137          105    QUEENS   2023-09-16     12:20:00
# 555114    272734727          105    QUEENS   2023-07-15     10:50:00
# 555115    270806588          105    QUEENS   2023-07-04     21:00:00
# 555116    263569764          105    QUEENS   2023-02-11     20:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  \
# 0        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    105
# 1        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    113
# 2        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    106
# 3        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# 4        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# ...             ...          ...              ...               ...    ...
# 555112   2023-12-12     21:12:00        COMPLETED  N.Y. POLICE DEPT    361
# 555113   2023-09-16     12:25:00        COMPLETED  N.Y. POLICE DEPT    344
# 555114   2023-07-15     11:00:00        COMPLETED  N.Y. POLICE DEPT    112
# 555115   2023-07-04     21:15:00        COMPLETED  N.Y. POLICE DEPT    126
# 555116   2023-02-14      5:45:00        COMPLETED  N.Y. POLICE DEPT    341
#
#          LAW_CAT_CD LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0            FELONY      NOT REPORTED                          ROBBERY    366
# 1            FELONY      NOT REPORTED                          FORGERY    725
# 2            FELONY          FRONT OF                   FELONY ASSAULT    105
# 3            FELONY           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# 4            FELONY           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# ...             ...               ...                              ...    ...
# 555112  MISDEMEANOR            INSIDE    OFF. AGNST PUB ORD SENSBLTY &    639
# 555113  MISDEMEANOR            INSIDE     ASSAULT 3 & RELATED OFFENSES    101
# 555114       FELONY            INSIDE                      THEFT-FRAUD    739
# 555115       FELONY      NOT REPORTED          MISCELLANEOUS PENAL LAW    117
# 555116  MISDEMEANOR          FRONT OF                    PETIT LARCENY    357
#
#                                PD_DESC            PREM_TYP_DESC     RPT_DT  \
# 0                      ROBBERY,BICYCLE                   STREET 2023-06-03
# 1            FORGERY,M.V. REGISTRATION                   STREET 2023-01-18
# 2                    STRANGULATION 1ST                   STREET 2023-05-09
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD 2023-02-06
# 4                         NOT REPORTED             NOT REPORTED 2023-06-04
# ...                                ...                      ...        ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE 2023-12-12
# 555113                       ASSAULT 3          RESIDENCE-HOUSE 2023-09-16
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED 2023-08-10
# 555115         RECKLESS ENDANGERMENT 1                   STREET 2023-07-04
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET 2023-02-12
#
#          Latitude  Longitude
# 0       40.824059 -73.899799
# 1       40.835859 -73.872125
# 2       40.831500 -73.863400
# 3        0.000000   0.000000
# 4        0.000000   0.000000
# ...           ...        ...
# 555112  40.712511 -73.734210
# 555113  40.728739 -73.711686
# 555114  40.732507 -73.717340
# 555115  40.711220 -73.728262
# 555116  40.711695 -73.732383
#
# [555117 rows x 19 columns]

# %%
# Combine date and time columns into a single datetime column
nypd_complaints_df['DATE_TIME'] = pd.to_datetime(nypd_complaints_df['CMPLNT_FR_DT'] + ' ' + nypd_complaints_df['CMPLNT_FR_TM'])

# Convert datetime column to ISO format
nypd_complaints_df['CMPLNT_FR_ISO'] = nypd_complaints_df['DATE_TIME'].dt.strftime('%Y-%m-%dT%H:%M:%S')


nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0         269235387           42     BRONX   2023-06-03      1:00:00
# 1         262102261           43     BRONX   2023-01-18     14:00:00
# 2         267972239           43     BRONX   2023-05-07      0:15:00
# 3       263141402H1            0  BROOKLYN   2023-02-06     10:16:00
# 4       269307857H1            0  BROOKLYN   2023-06-04      0:20:00
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12     21:00:00
# 555113    274543137          105    QUEENS   2023-09-16     12:20:00
# 555114    272734727          105    QUEENS   2023-07-15     10:50:00
# 555115    270806588          105    QUEENS   2023-07-04     21:00:00
# 555116    263569764          105    QUEENS   2023-02-11     20:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  \
# 0        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    105
# 1        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    113
# 2        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    106
# 3        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# 4        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# ...             ...          ...              ...               ...    ...
# 555112   2023-12-12     21:12:00        COMPLETED  N.Y. POLICE DEPT    361
# 555113   2023-09-16     12:25:00        COMPLETED  N.Y. POLICE DEPT    344
# 555114   2023-07-15     11:00:00        COMPLETED  N.Y. POLICE DEPT    112
# 555115   2023-07-04     21:15:00        COMPLETED  N.Y. POLICE DEPT    126
# 555116   2023-02-14      5:45:00        COMPLETED  N.Y. POLICE DEPT    341
#
#         ... LOC_OF_OCCUR_DESC                        OFNS_DESC PD_CD  \
# 0       ...      NOT REPORTED                          ROBBERY   366
# 1       ...      NOT REPORTED                          FORGERY   725
# 2       ...          FRONT OF                   FELONY ASSAULT   105
# 3       ...           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER     0
# 4       ...           OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER     0
# ...     ...               ...                              ...   ...
# 555112  ...            INSIDE    OFF. AGNST PUB ORD SENSBLTY &   639
# 555113  ...            INSIDE     ASSAULT 3 & RELATED OFFENSES   101
# 555114  ...            INSIDE                      THEFT-FRAUD   739
# 555115  ...      NOT REPORTED          MISCELLANEOUS PENAL LAW   117
# 555116  ...          FRONT OF                    PETIT LARCENY   357
#
#                                PD_DESC            PREM_TYP_DESC     RPT_DT  \
# 0                      ROBBERY,BICYCLE                   STREET 2023-06-03
# 1            FORGERY,M.V. REGISTRATION                   STREET 2023-01-18
# 2                    STRANGULATION 1ST                   STREET 2023-05-09
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD 2023-02-06
# 4                         NOT REPORTED             NOT REPORTED 2023-06-04
# ...                                ...                      ...        ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE 2023-12-12
# 555113                       ASSAULT 3          RESIDENCE-HOUSE 2023-09-16
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED 2023-08-10
# 555115         RECKLESS ENDANGERMENT 1                   STREET 2023-07-04
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET 2023-02-12
#
#          Latitude  Longitude           DATE_TIME        CMPLNT_FR_ISO
# 0       40.824059 -73.899799 2023-06-03 01:00:00  2023-06-03T01:00:00
# 1       40.835859 -73.872125 2023-01-18 14:00:00  2023-01-18T14:00:00
# 2       40.831500 -73.863400 2023-05-07 00:15:00  2023-05-07T00:15:00
# 3        0.000000   0.000000 2023-02-06 10:16:00  2023-02-06T10:16:00
# 4        0.000000   0.000000 2023-06-04 00:20:00  2023-06-04T00:20:00
# ...           ...        ...                 ...                  ...
# 555112  40.712511 -73.734210 2023-12-12 21:00:00  2023-12-12T21:00:00
# 555113  40.728739 -73.711686 2023-09-16 12:20:00  2023-09-16T12:20:00
# 555114  40.732507 -73.717340 2023-07-15 10:50:00  2023-07-15T10:50:00
# 555115  40.711220 -73.728262 2023-07-04 21:00:00  2023-07-04T21:00:00
# 555116  40.711695 -73.732383 2023-02-11 20:00:00  2023-02-11T20:00:00
#
# [555117 rows x 21 columns]

# %%
# Combine date and time columns into a single datetime column
nypd_complaints_df['DATE_TIME2'] = pd.to_datetime(nypd_complaints_df['CMPLNT_TO_DT'] + ' ' + nypd_complaints_df['CMPLNT_TO_TM'])

# Convert datetime column to ISO format
nypd_complaints_df['CMPLNT_TO_ISO'] = nypd_complaints_df['DATE_TIME2'].dt.strftime('%Y-%m-%dT%H:%M:%S')


nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0         269235387           42     BRONX   2023-06-03      1:00:00
# 1         262102261           43     BRONX   2023-01-18     14:00:00
# 2         267972239           43     BRONX   2023-05-07      0:15:00
# 3       263141402H1            0  BROOKLYN   2023-02-06     10:16:00
# 4       269307857H1            0  BROOKLYN   2023-06-04      0:20:00
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12     21:00:00
# 555113    274543137          105    QUEENS   2023-09-16     12:20:00
# 555114    272734727          105    QUEENS   2023-07-15     10:50:00
# 555115    270806588          105    QUEENS   2023-07-04     21:00:00
# 555116    263569764          105    QUEENS   2023-02-11     20:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD  \
# 0        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    105
# 1        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    113
# 2        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    106
# 3        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# 4        2023-12-31     23:59:59        COMPLETED  N.Y. POLICE DEPT    101
# ...             ...          ...              ...               ...    ...
# 555112   2023-12-12     21:12:00        COMPLETED  N.Y. POLICE DEPT    361
# 555113   2023-09-16     12:25:00        COMPLETED  N.Y. POLICE DEPT    344
# 555114   2023-07-15     11:00:00        COMPLETED  N.Y. POLICE DEPT    112
# 555115   2023-07-04     21:15:00        COMPLETED  N.Y. POLICE DEPT    126
# 555116   2023-02-14      5:45:00        COMPLETED  N.Y. POLICE DEPT    341
#
#         ... PD_CD                         PD_DESC            PREM_TYP_DESC  \
# 0       ...   366                 ROBBERY,BICYCLE                   STREET
# 1       ...   725       FORGERY,M.V. REGISTRATION                   STREET
# 2       ...   105               STRANGULATION 1ST                   STREET
# 3       ...     0                    NOT REPORTED  MULTI DWELL - APT BUILD
# 4       ...     0                    NOT REPORTED             NOT REPORTED
# ...     ...   ...                             ...                      ...
# 555112  ...   639         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE
# 555113  ...   101                       ASSAULT 3          RESIDENCE-HOUSE
# 555114  ...   739       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED
# 555115  ...   117         RECKLESS ENDANGERMENT 1                   STREET
# 555116  ...   357  LARCENY,PETIT OF VEHICLE ACCES                   STREET
#
#            RPT_DT   Latitude  Longitude           DATE_TIME  \
# 0      2023-06-03  40.824059 -73.899799 2023-06-03 01:00:00
# 1      2023-01-18  40.835859 -73.872125 2023-01-18 14:00:00
# 2      2023-05-09  40.831500 -73.863400 2023-05-07 00:15:00
# 3      2023-02-06   0.000000   0.000000 2023-02-06 10:16:00
# 4      2023-06-04   0.000000   0.000000 2023-06-04 00:20:00
# ...           ...        ...        ...                 ...
# 555112 2023-12-12  40.712511 -73.734210 2023-12-12 21:00:00
# 555113 2023-09-16  40.728739 -73.711686 2023-09-16 12:20:00
# 555114 2023-08-10  40.732507 -73.717340 2023-07-15 10:50:00
# 555115 2023-07-04  40.711220 -73.728262 2023-07-04 21:00:00
# 555116 2023-02-12  40.711695 -73.732383 2023-02-11 20:00:00
#
#               CMPLNT_FR_ISO          DATE_TIME2        CMPLNT_TO_ISO
# 0       2023-06-03T01:00:00 2023-12-31 23:59:59  2023-12-31T23:59:59
# 1       2023-01-18T14:00:00 2023-12-31 23:59:59  2023-12-31T23:59:59
# 2       2023-05-07T00:15:00 2023-12-31 23:59:59  2023-12-31T23:59:59
# 3       2023-02-06T10:16:00 2023-12-31 23:59:59  2023-12-31T23:59:59
# 4       2023-06-04T00:20:00 2023-12-31 23:59:59  2023-12-31T23:59:59
# ...                     ...                 ...                  ...
# 555112  2023-12-12T21:00:00 2023-12-12 21:12:00  2023-12-12T21:12:00
# 555113  2023-09-16T12:20:00 2023-09-16 12:25:00  2023-09-16T12:25:00
# 555114  2023-07-15T10:50:00 2023-07-15 11:00:00  2023-07-15T11:00:00
# 555115  2023-07-04T21:00:00 2023-07-04 21:15:00  2023-07-04T21:15:00
# 555116  2023-02-11T20:00:00 2023-02-14 05:45:00  2023-02-14T05:45:00
#
# [555117 rows x 23 columns]

# %%
#Drop time columns after the reformatting into Date ISO format
columns_to_drop = ['CMPLNT_FR_TM', 'CMPLNT_TO_TM', 'DATE_TIME', 'DATE_TIME2']

nypd_complaints_df.drop(columns=columns_to_drop, inplace=True)


nypd_complaints_df.head()
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0    269235387           42     BRONX   2023-06-03   2023-12-31
# 1    262102261           43     BRONX   2023-01-18   2023-12-31
# 2    267972239           43     BRONX   2023-05-07   2023-12-31
# 3  263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4  269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
#
#   CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD LAW_CAT_CD LOC_OF_OCCUR_DESC  \
# 0        COMPLETED  N.Y. POLICE DEPT    105     FELONY      NOT REPORTED
# 1        COMPLETED  N.Y. POLICE DEPT    113     FELONY      NOT REPORTED
# 2        COMPLETED  N.Y. POLICE DEPT    106     FELONY          FRONT OF
# 3        COMPLETED  N.Y. POLICE DEPT    101     FELONY           OUTSIDE
# 4        COMPLETED  N.Y. POLICE DEPT    101     FELONY           OUTSIDE
#
#                          OFNS_DESC  PD_CD                    PD_DESC  \
# 0                          ROBBERY    366            ROBBERY,BICYCLE
# 1                          FORGERY    725  FORGERY,M.V. REGISTRATION
# 2                   FELONY ASSAULT    105          STRANGULATION 1ST
# 3  MURDER & NON-NEGL. MANSLAUGHTER      0               NOT REPORTED
# 4  MURDER & NON-NEGL. MANSLAUGHTER      0               NOT REPORTED
#
#              PREM_TYP_DESC     RPT_DT   Latitude  Longitude  \
# 0                   STREET 2023-06-03  40.824059 -73.899799
# 1                   STREET 2023-01-18  40.835859 -73.872125
# 2                   STREET 2023-05-09  40.831500 -73.863400
# 3  MULTI DWELL - APT BUILD 2023-02-06   0.000000   0.000000
# 4             NOT REPORTED 2023-06-04   0.000000   0.000000
#
#          CMPLNT_FR_ISO        CMPLNT_TO_ISO
# 0  2023-06-03T01:00:00  2023-12-31T23:59:59
# 1  2023-01-18T14:00:00  2023-12-31T23:59:59
# 2  2023-05-07T00:15:00  2023-12-31T23:59:59
# 3  2023-02-06T10:16:00  2023-12-31T23:59:59
# 4  2023-06-04T00:20:00  2023-12-31T23:59:59

# %%
#Creating Jurisdiction ID


# Creating jurisdiction code Dimension
jurisdiction_mapping = {
    'N.Y. POLICE DEPT': 1,
    'N.Y. HOUSING POLICE': 2
}

# Map jurisdiction descriptions to codes and create a new column
nypd_complaints_df['JURISDICTION_ID'] = nypd_complaints_df['JURIS_DESC'].map(jurisdiction_mapping)

# Convert into whole integer
nypd_complaints_df['JURISDICTION_ID'] = nypd_complaints_df['JURISDICTION_ID'].astype('Int64')
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0         269235387           42     BRONX   2023-06-03   2023-12-31
# 1         262102261           43     BRONX   2023-01-18   2023-12-31
# 2         267972239           43     BRONX   2023-05-07   2023-12-31
# 3       263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4       269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12   2023-12-12
# 555113    274543137          105    QUEENS   2023-09-16   2023-09-16
# 555114    272734727          105    QUEENS   2023-07-15   2023-07-15
# 555115    270806588          105    QUEENS   2023-07-04   2023-07-04
# 555116    263569764          105    QUEENS   2023-02-11   2023-02-14
#
#        CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0             COMPLETED  N.Y. POLICE DEPT    105       FELONY
# 1             COMPLETED  N.Y. POLICE DEPT    113       FELONY
# 2             COMPLETED  N.Y. POLICE DEPT    106       FELONY
# 3             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# 4             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# ...                 ...               ...    ...          ...
# 555112        COMPLETED  N.Y. POLICE DEPT    361  MISDEMEANOR
# 555113        COMPLETED  N.Y. POLICE DEPT    344  MISDEMEANOR
# 555114        COMPLETED  N.Y. POLICE DEPT    112       FELONY
# 555115        COMPLETED  N.Y. POLICE DEPT    126       FELONY
# 555116        COMPLETED  N.Y. POLICE DEPT    341  MISDEMEANOR
#
#        LOC_OF_OCCUR_DESC                        OFNS_DESC  PD_CD  \
# 0           NOT REPORTED                          ROBBERY    366
# 1           NOT REPORTED                          FORGERY    725
# 2               FRONT OF                   FELONY ASSAULT    105
# 3                OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# 4                OUTSIDE  MURDER & NON-NEGL. MANSLAUGHTER      0
# ...                  ...                              ...    ...
# 555112            INSIDE    OFF. AGNST PUB ORD SENSBLTY &    639
# 555113            INSIDE     ASSAULT 3 & RELATED OFFENSES    101
# 555114            INSIDE                      THEFT-FRAUD    739
# 555115      NOT REPORTED          MISCELLANEOUS PENAL LAW    117
# 555116          FRONT OF                    PETIT LARCENY    357
#
#                                PD_DESC            PREM_TYP_DESC     RPT_DT  \
# 0                      ROBBERY,BICYCLE                   STREET 2023-06-03
# 1            FORGERY,M.V. REGISTRATION                   STREET 2023-01-18
# 2                    STRANGULATION 1ST                   STREET 2023-05-09
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD 2023-02-06
# 4                         NOT REPORTED             NOT REPORTED 2023-06-04
# ...                                ...                      ...        ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE 2023-12-12
# 555113                       ASSAULT 3          RESIDENCE-HOUSE 2023-09-16
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED 2023-08-10
# 555115         RECKLESS ENDANGERMENT 1                   STREET 2023-07-04
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET 2023-02-12
#
#          Latitude  Longitude        CMPLNT_FR_ISO        CMPLNT_TO_ISO  \
# 0       40.824059 -73.899799  2023-06-03T01:00:00  2023-12-31T23:59:59
# 1       40.835859 -73.872125  2023-01-18T14:00:00  2023-12-31T23:59:59
# 2       40.831500 -73.863400  2023-05-07T00:15:00  2023-12-31T23:59:59
# 3        0.000000   0.000000  2023-02-06T10:16:00  2023-12-31T23:59:59
# 4        0.000000   0.000000  2023-06-04T00:20:00  2023-12-31T23:59:59
# ...           ...        ...                  ...                  ...
# 555112  40.712511 -73.734210  2023-12-12T21:00:00  2023-12-12T21:12:00
# 555113  40.728739 -73.711686  2023-09-16T12:20:00  2023-09-16T12:25:00
# 555114  40.732507 -73.717340  2023-07-15T10:50:00  2023-07-15T11:00:00
# 555115  40.711220 -73.728262  2023-07-04T21:00:00  2023-07-04T21:15:00
# 555116  40.711695 -73.732383  2023-02-11T20:00:00  2023-02-14T05:45:00
#
#         JURISDICTION_ID
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 555112                1
# 555113                1
# 555114                1
# 555115                1
# 555116                1
#
# [555117 rows x 20 columns]

# %%
# Creating offense dimension


# Find unique levels in the "OFNS_DESC" column
unique_levels = nypd_complaints_df['OFNS_DESC'].unique()

print(unique_levels)
# Out:
# ['ROBBERY' 'FORGERY' 'FELONY ASSAULT' 'MURDER & NON-NEGL. MANSLAUGHTER'
#  'DANGEROUS DRUGS' 'ASSAULT 3 & RELATED OFFENSES'
#  'VEHICLE AND TRAFFIC LAWS' 'BURGLARY' 'SEX CRIMES' 'PETIT LARCENY'
#  'OTHER OFFENSES RELATED TO THEF' 'CRIMINAL MISCHIEF & RELATED OF'
#  'GRAND LARCENY OF MOTOR VEHICLE' 'HARRASSMENT 2' 'FRAUDS'
#  'OFF. AGNST PUB ORD SENSBLTY &' 'GRAND LARCENY'
#  'INTOXICATED & IMPAIRED DRIVING' 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED'
#  'MISCELLANEOUS PENAL LAW' 'DANGEROUS WEAPONS' 'THEFT-FRAUD' 'ARSON'
#  'UNAUTHORIZED USE OF A VEHICLE' 'OFFENSES AGAINST PUBLIC ADMINI'
#  'NYS LAWS-UNCLASSIFIED FELONY' 'CRIMINAL TRESPASS' 'RAPE'
#  'OFFENSES INVOLVING FRAUD' 'OTHER STATE LAWS (NON PENAL LA'
#  'PROSTITUTION & RELATED OFFENSES' 'OFFENSES AGAINST THE PERSON'
#  'OFFENSES AGAINST PUBLIC SAFETY' 'POSSESSION OF STOLEN PROPERTY'
#  'CANNABIS RELATED OFFENSES' 'KIDNAPPING & RELATED OFFENSES'
#  'OTHER STATE LAWS' 'ADMINISTRATIVE CODE' 'ENDAN WELFARE INCOMP' '(null)'
#  'NYS LAWS-UNCLASSIFIED VIOLATION' 'ESCAPE 3'
#  'HOMICIDE-NEGLIGENT,UNCLASSIFIE' "BURGLAR'S TOOLS"
#  'PETIT LARCENY OF MOTOR VEHICLE' 'CHILD ABANDONMENT/NON SUPPORT'
#  'GAMBLING' 'JOSTLING' 'ALCOHOLIC BEVERAGE CONTROL LAW'
#  'OFFENSES RELATED TO CHILDREN' 'INTOXICATED/IMPAIRED DRIVING'
#  'ANTICIPATORY OFFENSES' 'DISRUPTION OF A RELIGIOUS SERV' 'KIDNAPPING'
#  'FRAUDULENT ACCOSTING' 'THEFT OF SERVICES' 'NEW YORK CITY HEALTH CODE'
#  'OTHER TRAFFIC INFRACTION' 'DISORDERLY CONDUCT' 'FELONY SEX CRIMES'
#  'FORTUNE TELLING' 'HOMICIDE-NEGLIGENT-VEHICLE'
#  'UNLAWFUL POSS. WEAP. ON SCHOOL' 'LOITERING']

# %%
# Create Offense dimension

# Create a mapping dictionary for offenses to IDs
offense_mapping = {offense: idx + 1 for idx, offense in enumerate(nypd_complaints_df['OFNS_DESC'].unique())}

# Map offenses to IDs and create a new column
nypd_complaints_df['OFFENSE_ID'] = nypd_complaints_df['OFNS_DESC'].map(offense_mapping)

# %%
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0         269235387           42     BRONX   2023-06-03   2023-12-31
# 1         262102261           43     BRONX   2023-01-18   2023-12-31
# 2         267972239           43     BRONX   2023-05-07   2023-12-31
# 3       263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4       269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12   2023-12-12
# 555113    274543137          105    QUEENS   2023-09-16   2023-09-16
# 555114    272734727          105    QUEENS   2023-07-15   2023-07-15
# 555115    270806588          105    QUEENS   2023-07-04   2023-07-04
# 555116    263569764          105    QUEENS   2023-02-11   2023-02-14
#
#        CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0             COMPLETED  N.Y. POLICE DEPT    105       FELONY
# 1             COMPLETED  N.Y. POLICE DEPT    113       FELONY
# 2             COMPLETED  N.Y. POLICE DEPT    106       FELONY
# 3             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# 4             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# ...                 ...               ...    ...          ...
# 555112        COMPLETED  N.Y. POLICE DEPT    361  MISDEMEANOR
# 555113        COMPLETED  N.Y. POLICE DEPT    344  MISDEMEANOR
# 555114        COMPLETED  N.Y. POLICE DEPT    112       FELONY
# 555115        COMPLETED  N.Y. POLICE DEPT    126       FELONY
# 555116        COMPLETED  N.Y. POLICE DEPT    341  MISDEMEANOR
#
#        LOC_OF_OCCUR_DESC  ... PD_CD                         PD_DESC  \
# 0           NOT REPORTED  ...   366                 ROBBERY,BICYCLE
# 1           NOT REPORTED  ...   725       FORGERY,M.V. REGISTRATION
# 2               FRONT OF  ...   105               STRANGULATION 1ST
# 3                OUTSIDE  ...     0                    NOT REPORTED
# 4                OUTSIDE  ...     0                    NOT REPORTED
# ...                  ...  ...   ...                             ...
# 555112            INSIDE  ...   639         AGGRAVATED HARASSMENT 2
# 555113            INSIDE  ...   101                       ASSAULT 3
# 555114            INSIDE  ...   739       FRAUD,UNCLASSIFIED-FELONY
# 555115      NOT REPORTED  ...   117         RECKLESS ENDANGERMENT 1
# 555116          FRONT OF  ...   357  LARCENY,PETIT OF VEHICLE ACCES
#
#                   PREM_TYP_DESC     RPT_DT   Latitude  Longitude  \
# 0                        STREET 2023-06-03  40.824059 -73.899799
# 1                        STREET 2023-01-18  40.835859 -73.872125
# 2                        STREET 2023-05-09  40.831500 -73.863400
# 3       MULTI DWELL - APT BUILD 2023-02-06   0.000000   0.000000
# 4                  NOT REPORTED 2023-06-04   0.000000   0.000000
# ...                         ...        ...        ...        ...
# 555112   RESIDENCE - APT. HOUSE 2023-12-12  40.712511 -73.734210
# 555113          RESIDENCE-HOUSE 2023-09-16  40.728739 -73.711686
# 555114             NOT REPORTED 2023-08-10  40.732507 -73.717340
# 555115                   STREET 2023-07-04  40.711220 -73.728262
# 555116                   STREET 2023-02-12  40.711695 -73.732383
#
#               CMPLNT_FR_ISO        CMPLNT_TO_ISO JURISDICTION_ID  OFFENSE_ID
# 0       2023-06-03T01:00:00  2023-12-31T23:59:59               1           1
# 1       2023-01-18T14:00:00  2023-12-31T23:59:59               1           2
# 2       2023-05-07T00:15:00  2023-12-31T23:59:59               1           3
# 3       2023-02-06T10:16:00  2023-12-31T23:59:59               1           4
# 4       2023-06-04T00:20:00  2023-12-31T23:59:59               1           4
# ...                     ...                  ...             ...         ...
# 555112  2023-12-12T21:00:00  2023-12-12T21:12:00               1          16
# 555113  2023-09-16T12:20:00  2023-09-16T12:25:00               1           6
# 555114  2023-07-15T10:50:00  2023-07-15T11:00:00               1          22
# 555115  2023-07-04T21:00:00  2023-07-04T21:15:00               1          20
# 555116  2023-02-11T20:00:00  2023-02-14T05:45:00               1          10
#
# [555117 rows x 21 columns]

# %%
#Create location dimension

# Mapping dictionary
borough_mapping = {
    'BRONX': 1,
    'BROOKLYN': 2,
    'QUEENS': 3,
    'MANHATTAN': 4,
    'STATEN ISLAND': 5
}

# Map borough names to codes and create a new column
nypd_complaints_df['LOCATION_ID'] = nypd_complaints_df['BORO_NM'].map(borough_mapping)

nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0         269235387           42     BRONX   2023-06-03   2023-12-31
# 1         262102261           43     BRONX   2023-01-18   2023-12-31
# 2         267972239           43     BRONX   2023-05-07   2023-12-31
# 3       263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4       269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12   2023-12-12
# 555113    274543137          105    QUEENS   2023-09-16   2023-09-16
# 555114    272734727          105    QUEENS   2023-07-15   2023-07-15
# 555115    270806588          105    QUEENS   2023-07-04   2023-07-04
# 555116    263569764          105    QUEENS   2023-02-11   2023-02-14
#
#        CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0             COMPLETED  N.Y. POLICE DEPT    105       FELONY
# 1             COMPLETED  N.Y. POLICE DEPT    113       FELONY
# 2             COMPLETED  N.Y. POLICE DEPT    106       FELONY
# 3             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# 4             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# ...                 ...               ...    ...          ...
# 555112        COMPLETED  N.Y. POLICE DEPT    361  MISDEMEANOR
# 555113        COMPLETED  N.Y. POLICE DEPT    344  MISDEMEANOR
# 555114        COMPLETED  N.Y. POLICE DEPT    112       FELONY
# 555115        COMPLETED  N.Y. POLICE DEPT    126       FELONY
# 555116        COMPLETED  N.Y. POLICE DEPT    341  MISDEMEANOR
#
#        LOC_OF_OCCUR_DESC  ...                         PD_DESC  \
# 0           NOT REPORTED  ...                 ROBBERY,BICYCLE
# 1           NOT REPORTED  ...       FORGERY,M.V. REGISTRATION
# 2               FRONT OF  ...               STRANGULATION 1ST
# 3                OUTSIDE  ...                    NOT REPORTED
# 4                OUTSIDE  ...                    NOT REPORTED
# ...                  ...  ...                             ...
# 555112            INSIDE  ...         AGGRAVATED HARASSMENT 2
# 555113            INSIDE  ...                       ASSAULT 3
# 555114            INSIDE  ...       FRAUD,UNCLASSIFIED-FELONY
# 555115      NOT REPORTED  ...         RECKLESS ENDANGERMENT 1
# 555116          FRONT OF  ...  LARCENY,PETIT OF VEHICLE ACCES
#
#                   PREM_TYP_DESC     RPT_DT   Latitude  Longitude  \
# 0                        STREET 2023-06-03  40.824059 -73.899799
# 1                        STREET 2023-01-18  40.835859 -73.872125
# 2                        STREET 2023-05-09  40.831500 -73.863400
# 3       MULTI DWELL - APT BUILD 2023-02-06   0.000000   0.000000
# 4                  NOT REPORTED 2023-06-04   0.000000   0.000000
# ...                         ...        ...        ...        ...
# 555112   RESIDENCE - APT. HOUSE 2023-12-12  40.712511 -73.734210
# 555113          RESIDENCE-HOUSE 2023-09-16  40.728739 -73.711686
# 555114             NOT REPORTED 2023-08-10  40.732507 -73.717340
# 555115                   STREET 2023-07-04  40.711220 -73.728262
# 555116                   STREET 2023-02-12  40.711695 -73.732383
#
#               CMPLNT_FR_ISO        CMPLNT_TO_ISO JURISDICTION_ID OFFENSE_ID  \
# 0       2023-06-03T01:00:00  2023-12-31T23:59:59               1          1
# 1       2023-01-18T14:00:00  2023-12-31T23:59:59               1          2
# 2       2023-05-07T00:15:00  2023-12-31T23:59:59               1          3
# 3       2023-02-06T10:16:00  2023-12-31T23:59:59               1          4
# 4       2023-06-04T00:20:00  2023-12-31T23:59:59               1          4
# ...                     ...                  ...             ...        ...
# 555112  2023-12-12T21:00:00  2023-12-12T21:12:00               1         16
# 555113  2023-09-16T12:20:00  2023-09-16T12:25:00               1          6
# 555114  2023-07-15T10:50:00  2023-07-15T11:00:00               1         22
# 555115  2023-07-04T21:00:00  2023-07-04T21:15:00               1         20
# 555116  2023-02-11T20:00:00  2023-02-14T05:45:00               1         10
#
#         LOCATION_ID
# 0               1.0
# 1               1.0
# 2               1.0
# 3               2.0
# 4               2.0
# ...             ...
# 555112          3.0
# 555113          3.0
# 555114          3.0
# 555115          3.0
# 555116          3.0
#
# [555117 rows x 22 columns]

# %%
nypd_complaints_df['LOCATION_ID'] = nypd_complaints_df['LOCATION_ID'].astype('Int64')
nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0         269235387           42     BRONX   2023-06-03   2023-12-31
# 1         262102261           43     BRONX   2023-01-18   2023-12-31
# 2         267972239           43     BRONX   2023-05-07   2023-12-31
# 3       263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4       269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12   2023-12-12
# 555113    274543137          105    QUEENS   2023-09-16   2023-09-16
# 555114    272734727          105    QUEENS   2023-07-15   2023-07-15
# 555115    270806588          105    QUEENS   2023-07-04   2023-07-04
# 555116    263569764          105    QUEENS   2023-02-11   2023-02-14
#
#        CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0             COMPLETED  N.Y. POLICE DEPT    105       FELONY
# 1             COMPLETED  N.Y. POLICE DEPT    113       FELONY
# 2             COMPLETED  N.Y. POLICE DEPT    106       FELONY
# 3             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# 4             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# ...                 ...               ...    ...          ...
# 555112        COMPLETED  N.Y. POLICE DEPT    361  MISDEMEANOR
# 555113        COMPLETED  N.Y. POLICE DEPT    344  MISDEMEANOR
# 555114        COMPLETED  N.Y. POLICE DEPT    112       FELONY
# 555115        COMPLETED  N.Y. POLICE DEPT    126       FELONY
# 555116        COMPLETED  N.Y. POLICE DEPT    341  MISDEMEANOR
#
#        LOC_OF_OCCUR_DESC  ...                         PD_DESC  \
# 0           NOT REPORTED  ...                 ROBBERY,BICYCLE
# 1           NOT REPORTED  ...       FORGERY,M.V. REGISTRATION
# 2               FRONT OF  ...               STRANGULATION 1ST
# 3                OUTSIDE  ...                    NOT REPORTED
# 4                OUTSIDE  ...                    NOT REPORTED
# ...                  ...  ...                             ...
# 555112            INSIDE  ...         AGGRAVATED HARASSMENT 2
# 555113            INSIDE  ...                       ASSAULT 3
# 555114            INSIDE  ...       FRAUD,UNCLASSIFIED-FELONY
# 555115      NOT REPORTED  ...         RECKLESS ENDANGERMENT 1
# 555116          FRONT OF  ...  LARCENY,PETIT OF VEHICLE ACCES
#
#                   PREM_TYP_DESC     RPT_DT   Latitude  Longitude  \
# 0                        STREET 2023-06-03  40.824059 -73.899799
# 1                        STREET 2023-01-18  40.835859 -73.872125
# 2                        STREET 2023-05-09  40.831500 -73.863400
# 3       MULTI DWELL - APT BUILD 2023-02-06   0.000000   0.000000
# 4                  NOT REPORTED 2023-06-04   0.000000   0.000000
# ...                         ...        ...        ...        ...
# 555112   RESIDENCE - APT. HOUSE 2023-12-12  40.712511 -73.734210
# 555113          RESIDENCE-HOUSE 2023-09-16  40.728739 -73.711686
# 555114             NOT REPORTED 2023-08-10  40.732507 -73.717340
# 555115                   STREET 2023-07-04  40.711220 -73.728262
# 555116                   STREET 2023-02-12  40.711695 -73.732383
#
#               CMPLNT_FR_ISO        CMPLNT_TO_ISO JURISDICTION_ID OFFENSE_ID  \
# 0       2023-06-03T01:00:00  2023-12-31T23:59:59               1          1
# 1       2023-01-18T14:00:00  2023-12-31T23:59:59               1          2
# 2       2023-05-07T00:15:00  2023-12-31T23:59:59               1          3
# 3       2023-02-06T10:16:00  2023-12-31T23:59:59               1          4
# 4       2023-06-04T00:20:00  2023-12-31T23:59:59               1          4
# ...                     ...                  ...             ...        ...
# 555112  2023-12-12T21:00:00  2023-12-12T21:12:00               1         16
# 555113  2023-09-16T12:20:00  2023-09-16T12:25:00               1          6
# 555114  2023-07-15T10:50:00  2023-07-15T11:00:00               1         22
# 555115  2023-07-04T21:00:00  2023-07-04T21:15:00               1         20
# 555116  2023-02-11T20:00:00  2023-02-14T05:45:00               1         10
#
#         LOCATION_ID
# 0                 1
# 1                 1
# 2                 1
# 3                 2
# 4                 2
# ...             ...
# 555112            3
# 555113            3
# 555114            3
# 555115            3
# 555116            3
#
# [555117 rows x 22 columns]

# %%
#Find Earliest Date

# Convert 'CMPLNT_FR_DT' to datetime type
nypd_complaints_df['CMPLNT_FR_DT'] = pd.to_datetime(nypd_complaints_df['CMPLNT_FR_DT'])

# Find the earliest date
earliest_date = nypd_complaints_df['CMPLNT_FR_DT'].min()

print("Earliest Date:", earliest_date)
# Out:
# Earliest Date: 1922-03-30 00:00:00

# %%
#Find latest Date

# Convert 'CMPLNT_FR_DT' to datetime type
nypd_complaints_df['CMPLNT_FR_DT'] = pd.to_datetime(nypd_complaints_df['CMPLNT_FR_DT'])

# Find the earliest date
latest_date = nypd_complaints_df['CMPLNT_FR_DT'].max()

print("latest_date:", latest_date)
# Out:
# latest_date: 2023-12-31 00:00:00

# %%
#Create a date ID and add new column to data frame 

# Convert 'RPT_DT' to string type and remove hyphens
nypd_complaints_df['DATE_ID'] = nypd_complaints_df['RPT_DT'].astype(str).str.replace('-', '')

# Add a unique identifier
nypd_complaints_df['DATE_ID'] = nypd_complaints_df['DATE_ID'] + '_' + nypd_complaints_df.index.astype(str)

nypd_complaints_df
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0         269235387           42     BRONX   2023-06-03   2023-12-31
# 1         262102261           43     BRONX   2023-01-18   2023-12-31
# 2         267972239           43     BRONX   2023-05-07   2023-12-31
# 3       263141402H1            0  BROOKLYN   2023-02-06   2023-12-31
# 4       269307857H1            0  BROOKLYN   2023-06-04   2023-12-31
# ...             ...          ...       ...          ...          ...
# 555112    278932501          105    QUEENS   2023-12-12   2023-12-12
# 555113    274543137          105    QUEENS   2023-09-16   2023-09-16
# 555114    272734727          105    QUEENS   2023-07-15   2023-07-15
# 555115    270806588          105    QUEENS   2023-07-04   2023-07-04
# 555116    263569764          105    QUEENS   2023-02-11   2023-02-14
#
#        CRM_ATPT_CPTD_CD        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0             COMPLETED  N.Y. POLICE DEPT    105       FELONY
# 1             COMPLETED  N.Y. POLICE DEPT    113       FELONY
# 2             COMPLETED  N.Y. POLICE DEPT    106       FELONY
# 3             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# 4             COMPLETED  N.Y. POLICE DEPT    101       FELONY
# ...                 ...               ...    ...          ...
# 555112        COMPLETED  N.Y. POLICE DEPT    361  MISDEMEANOR
# 555113        COMPLETED  N.Y. POLICE DEPT    344  MISDEMEANOR
# 555114        COMPLETED  N.Y. POLICE DEPT    112       FELONY
# 555115        COMPLETED  N.Y. POLICE DEPT    126       FELONY
# 555116        COMPLETED  N.Y. POLICE DEPT    341  MISDEMEANOR
#
#        LOC_OF_OCCUR_DESC  ...            PREM_TYP_DESC     RPT_DT   Latitude  \
# 0           NOT REPORTED  ...                   STREET 2023-06-03  40.824059
# 1           NOT REPORTED  ...                   STREET 2023-01-18  40.835859
# 2               FRONT OF  ...                   STREET 2023-05-09  40.831500
# 3                OUTSIDE  ...  MULTI DWELL - APT BUILD 2023-02-06   0.000000
# 4                OUTSIDE  ...             NOT REPORTED 2023-06-04   0.000000
# ...                  ...  ...                      ...        ...        ...
# 555112            INSIDE  ...   RESIDENCE - APT. HOUSE 2023-12-12  40.712511
# 555113            INSIDE  ...          RESIDENCE-HOUSE 2023-09-16  40.728739
# 555114            INSIDE  ...             NOT REPORTED 2023-08-10  40.732507
# 555115      NOT REPORTED  ...                   STREET 2023-07-04  40.711220
# 555116          FRONT OF  ...                   STREET 2023-02-12  40.711695
#
#         Longitude        CMPLNT_FR_ISO        CMPLNT_TO_ISO  JURISDICTION_ID  \
# 0      -73.899799  2023-06-03T01:00:00  2023-12-31T23:59:59                1
# 1      -73.872125  2023-01-18T14:00:00  2023-12-31T23:59:59                1
# 2      -73.863400  2023-05-07T00:15:00  2023-12-31T23:59:59                1
# 3        0.000000  2023-02-06T10:16:00  2023-12-31T23:59:59                1
# 4        0.000000  2023-06-04T00:20:00  2023-12-31T23:59:59                1
# ...           ...                  ...                  ...              ...
# 555112 -73.734210  2023-12-12T21:00:00  2023-12-12T21:12:00                1
# 555113 -73.711686  2023-09-16T12:20:00  2023-09-16T12:25:00                1
# 555114 -73.717340  2023-07-15T10:50:00  2023-07-15T11:00:00                1
# 555115 -73.728262  2023-07-04T21:00:00  2023-07-04T21:15:00                1
# 555116 -73.732383  2023-02-11T20:00:00  2023-02-14T05:45:00                1
#
#        OFFENSE_ID LOCATION_ID          DATE_ID
# 0               1           1       20230603_0
# 1               2           1       20230118_1
# 2               3           1       20230509_2
# 3               4           2       20230206_3
# 4               4           2       20230604_4
# ...           ...         ...              ...
# 555112         16           3  20231212_555112
# 555113          6           3  20230916_555113
# 555114         22           3  20230810_555114
# 555115         20           3  20230704_555115
# 555116         10           3  20230212_555116
#
# [555117 rows x 23 columns]

# %%
def week_of_month(dt):
    year = dt.year
    month = dt.month
    day = dt.day

    cal = calendar.monthcalendar(year, month)
    week_number = (day - 1) // 7 + 1
    return week_number

start_date = pd.to_datetime('1922-03-30')
end_date = pd.to_datetime('2023-12-31')
# Create a DataFrame for the date dimension
date_dimension = pd.DataFrame({'date': pd.date_range(start_date, end_date, freq='H')})

date_dimension.head(25)
# Out:
#                   date
# 0  1922-03-30 00:00:00
# 1  1922-03-30 01:00:00
# 2  1922-03-30 02:00:00
# 3  1922-03-30 03:00:00
# 4  1922-03-30 04:00:00
# 5  1922-03-30 05:00:00
# 6  1922-03-30 06:00:00
# 7  1922-03-30 07:00:00
# 8  1922-03-30 08:00:00
# 9  1922-03-30 09:00:00
# 10 1922-03-30 10:00:00
# 11 1922-03-30 11:00:00
# 12 1922-03-30 12:00:00
# 13 1922-03-30 13:00:00
# 14 1922-03-30 14:00:00
# 15 1922-03-30 15:00:00
# 16 1922-03-30 16:00:00
# 17 1922-03-30 17:00:00
# 18 1922-03-30 18:00:00
# 19 1922-03-30 19:00:00
# 20 1922-03-30 20:00:00
# 21 1922-03-30 21:00:00
# 22 1922-03-30 22:00:00
# 23 1922-03-30 23:00:00
# 24 1922-03-31 00:00:00

# %%
# Extract attributes
date_dimension['year_number'] = date_dimension['date'].dt.year
date_dimension['month_number'] = date_dimension['date'].dt.month
date_dimension['monthName'] = date_dimension['date'].dt.strftime('%B')
date_dimension['daynumber'] = date_dimension['date'].dt.day
date_dimension['dayName'] = date_dimension['date'].dt.strftime('%A')
date_dimension['date_iso_format'] = date_dimension['date'].apply(lambda x: x.isoformat())
date_dimension['DATE_ID'] = date_dimension['date'].dt.strftime('%Y%m%d%H')


new_order = ['DATE_ID', 'date_iso_format','year_number','month_number','daynumber','monthName','dayName']
date_dimension = date_dimension[new_order]

date_dimension.head(25)
# Out:
#        DATE_ID      date_iso_format  year_number  month_number  daynumber  \
# 0   1922033000  1922-03-30T00:00:00         1922             3         30
# 1   1922033001  1922-03-30T01:00:00         1922             3         30
# 2   1922033002  1922-03-30T02:00:00         1922             3         30
# 3   1922033003  1922-03-30T03:00:00         1922             3         30
# 4   1922033004  1922-03-30T04:00:00         1922             3         30
# 5   1922033005  1922-03-30T05:00:00         1922             3         30
# 6   1922033006  1922-03-30T06:00:00         1922             3         30
# 7   1922033007  1922-03-30T07:00:00         1922             3         30
# 8   1922033008  1922-03-30T08:00:00         1922             3         30
# 9   1922033009  1922-03-30T09:00:00         1922             3         30
# 10  1922033010  1922-03-30T10:00:00         1922             3         30
# 11  1922033011  1922-03-30T11:00:00         1922             3         30
# 12  1922033012  1922-03-30T12:00:00         1922             3         30
# 13  1922033013  1922-03-30T13:00:00         1922             3         30
# 14  1922033014  1922-03-30T14:00:00         1922             3         30
# 15  1922033015  1922-03-30T15:00:00         1922             3         30
# 16  1922033016  1922-03-30T16:00:00         1922             3         30
# 17  1922033017  1922-03-30T17:00:00         1922             3         30
# 18  1922033018  1922-03-30T18:00:00         1922             3         30
# 19  1922033019  1922-03-30T19:00:00         1922             3         30
# 20  1922033020  1922-03-30T20:00:00         1922             3         30
# 21  1922033021  1922-03-30T21:00:00         1922             3         30
# 22  1922033022  1922-03-30T22:00:00         1922             3         30
# 23  1922033023  1922-03-30T23:00:00         1922             3         30
# 24  1922033100  1922-03-31T00:00:00         1922             3         31
#
#    monthName   dayName
# 0      March  Thursday
# 1      March  Thursday
# 2      March  Thursday
# 3      March  Thursday
# 4      March  Thursday
# 5      March  Thursday
# 6      March  Thursday
# 7      March  Thursday
# 8      March  Thursday
# 9      March  Thursday
# 10     March  Thursday
# 11     March  Thursday
# 12     March  Thursday
# 13     March  Thursday
# 14     March  Thursday
# 15     March  Thursday
# 16     March  Thursday
# 17     March  Thursday
# 18     March  Thursday
# 19     March  Thursday
# 20     March  Thursday
# 21     March  Thursday
# 22     March  Thursday
# 23     March  Thursday
# 24     March    Friday

# %%
nypd_complaints_df.head(25)
# Out:
#      CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_TO_DT  \
# 0     269235387           42          BRONX   2023-06-03   2023-12-31
# 1     262102261           43          BRONX   2023-01-18   2023-12-31
# 2     267972239           43          BRONX   2023-05-07   2023-12-31
# 3   263141402H1            0       BROOKLYN   2023-02-06   2023-12-31
# 4   269307857H1            0       BROOKLYN   2023-06-04   2023-12-31
# 5   277525074H3            0         QUEENS   2023-11-14   2023-12-31
# 6   277525074H1            0         QUEENS   2023-11-14   2023-12-31
# 7   271421229H1            0       BROOKLYN   2020-07-05   2023-12-31
# 8   270206142H1            0      MANHATTAN   2023-06-21   2023-12-31
# 9     278972931          123  STATEN ISLAND   2023-12-14   2023-12-14
# 10    278470767          121  STATEN ISLAND   2023-12-04   2023-12-04
# 11    262794218          123  STATEN ISLAND   2023-02-01   2023-02-01
# 12    267066385          123  STATEN ISLAND   2023-04-22   2023-12-31
# 13    266228476          123  STATEN ISLAND   2023-04-02   2023-04-02
# 14    262909178          121  STATEN ISLAND   2023-02-02   2023-02-02
# 15    273942557          121  STATEN ISLAND   2023-09-05   2023-09-05
# 16    270654701          121  STATEN ISLAND   2023-07-01   2023-07-01
# 17    264963813          121  STATEN ISLAND   2023-03-10   2023-03-11
# 18    269416452          121  STATEN ISLAND   2023-06-03   2023-06-05
# 19    265515717          121  STATEN ISLAND   2023-03-22   2023-03-22
# 20    277212836          121  STATEN ISLAND   2023-09-29   2023-09-29
# 21    271742549          121  STATEN ISLAND   2023-07-20   2023-07-20
# 22    274989794          123  STATEN ISLAND   2023-09-26   2023-09-26
# 23    273607855          122  STATEN ISLAND   2023-08-29   2023-08-29
# 24    262601039          122  STATEN ISLAND   2023-01-26   2023-01-27
#
#    CRM_ATPT_CPTD_CD           JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0         COMPLETED     N.Y. POLICE DEPT    105       FELONY
# 1         COMPLETED     N.Y. POLICE DEPT    113       FELONY
# 2         COMPLETED     N.Y. POLICE DEPT    106       FELONY
# 3         COMPLETED     N.Y. POLICE DEPT    101       FELONY
# 4         COMPLETED     N.Y. POLICE DEPT    101       FELONY
# 5         COMPLETED     N.Y. POLICE DEPT    101       FELONY
# 6         COMPLETED     N.Y. POLICE DEPT    101       FELONY
# 7         COMPLETED  N.Y. HOUSING POLICE    101       FELONY
# 8         COMPLETED     N.Y. POLICE DEPT    101       FELONY
# 9         COMPLETED     N.Y. POLICE DEPT    235  MISDEMEANOR
# 10        COMPLETED     N.Y. POLICE DEPT    344  MISDEMEANOR
# 11        COMPLETED     N.Y. POLICE DEPT    344  MISDEMEANOR
# 12        COMPLETED     N.Y. POLICE DEPT    348  MISDEMEANOR
# 13        COMPLETED     N.Y. POLICE DEPT    344  MISDEMEANOR
# 14        COMPLETED     N.Y. POLICE DEPT    106       FELONY
# 15        COMPLETED     N.Y. POLICE DEPT    344  MISDEMEANOR
# 16        ATTEMPTED     N.Y. POLICE DEPT    107       FELONY
# 17        COMPLETED     N.Y. POLICE DEPT    233  MISDEMEANOR
# 18        COMPLETED     N.Y. POLICE DEPT    341  MISDEMEANOR
# 19        COMPLETED     N.Y. POLICE DEPT    343  MISDEMEANOR
# 20        COMPLETED     N.Y. POLICE DEPT    341  MISDEMEANOR
# 21        COMPLETED     N.Y. POLICE DEPT    351  MISDEMEANOR
# 22        COMPLETED     N.Y. POLICE DEPT    106       FELONY
# 23        COMPLETED     N.Y. POLICE DEPT    110       FELONY
# 24        COMPLETED     N.Y. POLICE DEPT    110       FELONY
#
#    LOC_OF_OCCUR_DESC  ...              PREM_TYP_DESC     RPT_DT   Latitude  \
# 0       NOT REPORTED  ...                     STREET 2023-06-03  40.824059
# 1       NOT REPORTED  ...                     STREET 2023-01-18  40.835859
# 2           FRONT OF  ...                     STREET 2023-05-09  40.831500
# 3            OUTSIDE  ...    MULTI DWELL - APT BUILD 2023-02-06   0.000000
# 4            OUTSIDE  ...               NOT REPORTED 2023-06-04   0.000000
# 5             INSIDE  ...                  PVT HOUSE 2023-11-14   0.000000
# 6             INSIDE  ...                  PVT HOUSE 2023-11-14   0.000000
# 7            OUTSIDE  ...  MULTI DWELL - PUBLIC HOUS 2023-07-05   0.000000
# 8            OUTSIDE  ...               NOT REPORTED 2023-06-21   0.000000
# 9       NOT REPORTED  ...                     STREET 2023-12-14  40.546531
# 10      NOT REPORTED  ...                     STREET 2023-12-04  40.626742
# 11            INSIDE  ...            RESIDENCE-HOUSE 2023-02-01  40.547045
# 12      NOT REPORTED  ...                     STREET 2023-04-22  40.524740
# 13          FRONT OF  ...             BAR/NIGHT CLUB 2023-04-05  40.514779
# 14            INSIDE  ...         SOCIAL CLUB/POLICY 2023-02-02  40.634491
# 15          FRONT OF  ...               NOT REPORTED 2023-09-05  40.584583
# 16          FRONT OF  ...            RESIDENCE-HOUSE 2023-07-01  40.631010
# 17            INSIDE  ...           HOMELESS SHELTER 2023-03-11  40.623188
# 18            INSIDE  ...                     STREET 2023-06-06  40.611720
# 19          FRONT OF  ...            RESIDENCE-HOUSE 2023-03-22  40.631337
# 20            INSIDE  ...                      OTHER 2023-11-08  40.587384
# 21            INSIDE  ...            RESIDENCE-HOUSE 2023-07-20  40.628100
# 22            INSIDE  ...            RESIDENCE-HOUSE 2023-09-26  40.536121
# 23          FRONT OF  ...                     STREET 2023-08-29  40.550329
# 24          FRONT OF  ...                     STREET 2023-01-27  40.553376
#
#     Longitude        CMPLNT_FR_ISO        CMPLNT_TO_ISO  JURISDICTION_ID  \
# 0  -73.899799  2023-06-03T01:00:00  2023-12-31T23:59:59                1
# 1  -73.872125  2023-01-18T14:00:00  2023-12-31T23:59:59                1
# 2  -73.863400  2023-05-07T00:15:00  2023-12-31T23:59:59                1
# 3    0.000000  2023-02-06T10:16:00  2023-12-31T23:59:59                1
# 4    0.000000  2023-06-04T00:20:00  2023-12-31T23:59:59                1
# 5    0.000000  2023-11-14T07:05:00  2023-12-31T23:59:59                1
# 6    0.000000  2023-11-14T07:05:00  2023-12-31T23:59:59                1
# 7    0.000000  2020-07-05T21:45:00  2023-12-31T23:59:59                2
# 8    0.000000  2023-06-21T16:25:00  2023-12-31T23:59:59                1
# 9  -74.180430  2023-12-14T02:50:00  2023-12-14T02:52:00                1
# 10 -74.139049  2023-12-04T15:53:00  2023-12-04T16:00:00                1
# 11 -74.220517  2023-02-01T01:35:00  2023-02-01T01:40:00                1
# 12 -74.233435  2023-04-22T01:14:00  2023-12-31T23:59:59                1
# 13 -74.248458  2023-04-02T00:20:00  2023-04-02T00:25:00                1
# 14 -74.131551  2023-02-02T12:05:00  2023-02-02T12:10:00                1
# 15 -74.162327  2023-09-05T20:30:00  2023-09-05T20:47:00                1
# 16 -74.160384  2023-07-01T05:25:00  2023-07-01T05:32:00                1
# 17 -74.149238  2023-03-10T17:00:00  2023-03-11T11:45:00                1
# 18 -74.160710  2023-06-03T12:00:00  2023-06-05T22:00:00                1
# 19 -74.135322  2023-03-22T15:00:00  2023-03-22T16:23:00                1
# 20 -74.191042  2023-09-29T08:00:00  2023-09-29T18:00:00                1
# 21 -74.142105  2023-07-20T12:00:00  2023-07-20T15:00:00                1
# 22 -74.177335  2023-09-26T20:45:00  2023-09-26T21:00:00                1
# 23 -74.140489  2023-08-29T09:00:00  2023-08-29T13:10:00                1
# 24 -74.162929  2023-01-26T19:00:00  2023-01-27T08:50:00                1
#
#    OFFENSE_ID LOCATION_ID      DATE_ID
# 0           1           1   20230603_0
# 1           2           1   20230118_1
# 2           3           1   20230509_2
# 3           4           2   20230206_3
# 4           4           2   20230604_4
# 5           4           3   20231114_5
# 6           4           3   20231114_6
# 7           4           2   20230705_7
# 8           4           4   20230621_8
# 9           5           5   20231214_9
# 10          6           5  20231204_10
# 11          6           5  20230201_11
# 12          7           5  20230422_12
# 13          6           5  20230405_13
# 14          3           5  20230202_14
# 15          6           5  20230905_15
# 16          8           5  20230701_16
# 17          9           5  20230311_17
# 18         10           5  20230606_18
# 19         11           5  20230322_19
# 20         10           5  20231108_20
# 21         12           5  20230720_21
# 22          3           5  20230926_22
# 23         13           5  20230829_23
# 24         13           5  20230127_24
#
# [25 rows x 23 columns]

# %%
nypd_complaints_df.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_TO_DT',
#        'CRM_ATPT_CPTD_CD', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PD_CD', 'PD_DESC', 'PREM_TYP_DESC',
#        'RPT_DT', 'Latitude', 'Longitude', 'CMPLNT_FR_ISO', 'CMPLNT_TO_ISO',
#        'JURISDICTION_ID', 'OFFENSE_ID', 'LOCATION_ID', 'DATE_ID'],
#       dtype='object')

# %%
new_order = ['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'DATE_ID','RPT_DT', 'CMPLNT_FR_DT','CMPLNT_FR_ISO', 'CMPLNT_TO_DT', 'CMPLNT_TO_ISO', 'JURISDICTION_ID', 'JURIS_DESC', 'OFFENSE_ID', 'KY_CD',
             'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC', 'PREM_TYP_DESC', 'LOC_OF_OCCUR_DESC', 'LOCATION_ID', 'Latitude', 'Longitude'] 

nypd_complaints_df = nypd_complaints_df[new_order]
nypd_complaints_df.head()
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD   BORO_NM     DATE_ID     RPT_DT CMPLNT_FR_DT  \
# 0    269235387           42     BRONX  20230603_0 2023-06-03   2023-06-03
# 1    262102261           43     BRONX  20230118_1 2023-01-18   2023-01-18
# 2    267972239           43     BRONX  20230509_2 2023-05-09   2023-05-07
# 3  263141402H1            0  BROOKLYN  20230206_3 2023-02-06   2023-02-06
# 4  269307857H1            0  BROOKLYN  20230604_4 2023-06-04   2023-06-04
#
#          CMPLNT_FR_ISO CMPLNT_TO_DT        CMPLNT_TO_ISO  JURISDICTION_ID  \
# 0  2023-06-03T01:00:00   2023-12-31  2023-12-31T23:59:59                1
# 1  2023-01-18T14:00:00   2023-12-31  2023-12-31T23:59:59                1
# 2  2023-05-07T00:15:00   2023-12-31  2023-12-31T23:59:59                1
# 3  2023-02-06T10:16:00   2023-12-31  2023-12-31T23:59:59                1
# 4  2023-06-04T00:20:00   2023-12-31  2023-12-31T23:59:59                1
#
#    ... CRM_ATPT_CPTD_CD  LAW_CAT_CD                        OFNS_DESC PD_CD  \
# 0  ...        COMPLETED      FELONY                          ROBBERY   366
# 1  ...        COMPLETED      FELONY                          FORGERY   725
# 2  ...        COMPLETED      FELONY                   FELONY ASSAULT   105
# 3  ...        COMPLETED      FELONY  MURDER & NON-NEGL. MANSLAUGHTER     0
# 4  ...        COMPLETED      FELONY  MURDER & NON-NEGL. MANSLAUGHTER     0
#
#                      PD_DESC            PREM_TYP_DESC  LOC_OF_OCCUR_DESC  \
# 0            ROBBERY,BICYCLE                   STREET       NOT REPORTED
# 1  FORGERY,M.V. REGISTRATION                   STREET       NOT REPORTED
# 2          STRANGULATION 1ST                   STREET           FRONT OF
# 3               NOT REPORTED  MULTI DWELL - APT BUILD            OUTSIDE
# 4               NOT REPORTED             NOT REPORTED            OUTSIDE
#
#   LOCATION_ID   Latitude  Longitude
# 0           1  40.824059 -73.899799
# 1           1  40.835859 -73.872125
# 2           1  40.831500 -73.863400
# 3           2   0.000000   0.000000
# 4           2   0.000000   0.000000
#
# [5 rows x 23 columns]

# %%
# Database connection URL
# Replace the placeholders with your actual database credentials
pwd = 'Baruch2024'
database_url = f'postgresql://jayramirez:{pwd}@cis9440-dw-baruch.postgres.database.azure.com/postgres'

# Create a SQLAlchemy engine
engine = create_engine(database_url)

# %%
# Extracting desired columns from nypd_complaints_df, offense dimension
offenses_dimension_df = nypd_complaints_df[['OFFENSE_ID', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC', 'PREM_TYP_DESC', 'LOC_OF_OCCUR_DESC']].copy()

# Display the new DataFrame
print(offenses_dimension_df)
# Out:
#         OFFENSE_ID CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 0                1        COMPLETED       FELONY
# 1                2        COMPLETED       FELONY
# 2                3        COMPLETED       FELONY
# 3                4        COMPLETED       FELONY
# 4                4        COMPLETED       FELONY
# ...            ...              ...          ...
# 555112          16        COMPLETED  MISDEMEANOR
# 555113           6        COMPLETED  MISDEMEANOR
# 555114          22        COMPLETED       FELONY
# 555115          20        COMPLETED       FELONY
# 555116          10        COMPLETED  MISDEMEANOR
#
#                               OFNS_DESC  PD_CD  \
# 0                               ROBBERY    366
# 1                               FORGERY    725
# 2                        FELONY ASSAULT    105
# 3       MURDER & NON-NEGL. MANSLAUGHTER      0
# 4       MURDER & NON-NEGL. MANSLAUGHTER      0
# ...                                 ...    ...
# 555112    OFF. AGNST PUB ORD SENSBLTY &    639
# 555113     ASSAULT 3 & RELATED OFFENSES    101
# 555114                      THEFT-FRAUD    739
# 555115          MISCELLANEOUS PENAL LAW    117
# 555116                    PETIT LARCENY    357
#
#                                PD_DESC            PREM_TYP_DESC  \
# 0                      ROBBERY,BICYCLE                   STREET
# 1            FORGERY,M.V. REGISTRATION                   STREET
# 2                    STRANGULATION 1ST                   STREET
# 3                         NOT REPORTED  MULTI DWELL - APT BUILD
# 4                         NOT REPORTED             NOT REPORTED
# ...                                ...                      ...
# 555112         AGGRAVATED HARASSMENT 2   RESIDENCE - APT. HOUSE
# 555113                       ASSAULT 3          RESIDENCE-HOUSE
# 555114       FRAUD,UNCLASSIFIED-FELONY             NOT REPORTED
# 555115         RECKLESS ENDANGERMENT 1                   STREET
# 555116  LARCENY,PETIT OF VEHICLE ACCES                   STREET
#
#        LOC_OF_OCCUR_DESC
# 0           NOT REPORTED
# 1           NOT REPORTED
# 2               FRONT OF
# 3                OUTSIDE
# 4                OUTSIDE
# ...                  ...
# 555112            INSIDE
# 555113            INSIDE
# 555114            INSIDE
# 555115      NOT REPORTED
# 555116          FRONT OF
#
# [555117 rows x 8 columns]

# %%
# Convert column names to lowercase
offenses_dimension_df.columns = map(str.lower, offenses_dimension_df.columns)

# %%
#Push offense data

# Push offense data to the data warehouse
offenses_dimension_df.to_sql('DIM_OFFENSE', con=engine, if_exists='append', index=False)
# Out:
# 117

# %%
# Jurisdiction dimension

# Extracting desired columns from nypd_complaints_df, jurisdiction dimension
jurisdiction_dimension_df = nypd_complaints_df[['JURISDICTION_ID', 'JURIS_DESC']].copy()

# Display the new DataFrame
print(jurisdiction_dimension_df)
# Out:
#         JURISDICTION_ID        JURIS_DESC
# 0                     1  N.Y. POLICE DEPT
# 1                     1  N.Y. POLICE DEPT
# 2                     1  N.Y. POLICE DEPT
# 3                     1  N.Y. POLICE DEPT
# 4                     1  N.Y. POLICE DEPT
# ...                 ...               ...
# 555112                1  N.Y. POLICE DEPT
# 555113                1  N.Y. POLICE DEPT
# 555114                1  N.Y. POLICE DEPT
# 555115                1  N.Y. POLICE DEPT
# 555116                1  N.Y. POLICE DEPT
#
# [555117 rows x 2 columns]

# %%
#Push jurisdiction data

# Push offense data to the data warehouse
jurisdiction_dimension_df.to_sql('DIM_JURISDICTION', con=engine, if_exists='append', index=False)
# Out:
# 117

# %%
# location dimension

# Extracting desired columns from nypd_complaints_df, location dimension
location_dimension_df = nypd_complaints_df[['LOCATION_ID', 'BORO_NM', 'Latitude', 'Longitude']].copy()

# Display the new DataFrame
print(location_dimension_df)
# Out:
#         LOCATION_ID   BORO_NM   Latitude  Longitude
# 0                 1     BRONX  40.824059 -73.899799
# 1                 1     BRONX  40.835859 -73.872125
# 2                 1     BRONX  40.831500 -73.863400
# 3                 2  BROOKLYN   0.000000   0.000000
# 4                 2  BROOKLYN   0.000000   0.000000
# ...             ...       ...        ...        ...
# 555112            3    QUEENS  40.712511 -73.734210
# 555113            3    QUEENS  40.728739 -73.711686
# 555114            3    QUEENS  40.732507 -73.717340
# 555115            3    QUEENS  40.711220 -73.728262
# 555116            3    QUEENS  40.711695 -73.732383
#
# [555117 rows x 4 columns]

# %%
#Push location data

# Push location data to the data warehouse
location_dimension_df.to_sql('DIM_LOCATION', con=engine, if_exists='append', index=False)
# Out:
# 117

# %%
# Date dimension

# Extracting desired columns from nypd_complaints_df, Date dimension
date_dimension_df = nypd_complaints_df[['DATE_ID', 'RPT_DT' ,'CMPLNT_FR_DT', 'CMPLNT_FR_ISO', 'CMPLNT_TO_DT', 'CMPLNT_TO_ISO']].copy()

# Display the new DataFrame
print(date_dimension_df)
# Out:
#                 DATE_ID     RPT_DT CMPLNT_FR_DT        CMPLNT_FR_ISO  \
# 0            20230603_0 2023-06-03   2023-06-03  2023-06-03T01:00:00
# 1            20230118_1 2023-01-18   2023-01-18  2023-01-18T14:00:00
# 2            20230509_2 2023-05-09   2023-05-07  2023-05-07T00:15:00
# 3            20230206_3 2023-02-06   2023-02-06  2023-02-06T10:16:00
# 4            20230604_4 2023-06-04   2023-06-04  2023-06-04T00:20:00
# ...                 ...        ...          ...                  ...
# 555112  20231212_555112 2023-12-12   2023-12-12  2023-12-12T21:00:00
# 555113  20230916_555113 2023-09-16   2023-09-16  2023-09-16T12:20:00
# 555114  20230810_555114 2023-08-10   2023-07-15  2023-07-15T10:50:00
# 555115  20230704_555115 2023-07-04   2023-07-04  2023-07-04T21:00:00
# 555116  20230212_555116 2023-02-12   2023-02-11  2023-02-11T20:00:00
#
#        CMPLNT_TO_DT        CMPLNT_TO_ISO
# 0        2023-12-31  2023-12-31T23:59:59
# 1        2023-12-31  2023-12-31T23:59:59
# 2        2023-12-31  2023-12-31T23:59:59
# 3        2023-12-31  2023-12-31T23:59:59
# 4        2023-12-31  2023-12-31T23:59:59
# ...             ...                  ...
# 555112   2023-12-12  2023-12-12T21:12:00
# 555113   2023-09-16  2023-09-16T12:25:00
# 555114   2023-07-15  2023-07-15T11:00:00
# 555115   2023-07-04  2023-07-04T21:15:00
# 555116   2023-02-14  2023-02-14T05:45:00
#
# [555117 rows x 6 columns]

# %%
#Push Date Dimension

date_dimension_df.to_sql('DIM_DATE', con=engine, if_exists='append', index=False)
# Out:
# 117

# %%
# Facts dimension

# Extracting desired columns from nypd_complaints_df, facts dimension
facts_complaints_df = nypd_complaints_df[['CMPLNT_NUM', 'ADDR_PCT_CD' ,'KY_CD', 'LOCATION_ID', 'DATE_ID', 'OFFENSE_ID', 'JURISDICTION_ID']].copy()

# Display the new DataFrame
print(facts_complaints_df)
# Out:
#          CMPLNT_NUM  ADDR_PCT_CD  KY_CD  LOCATION_ID          DATE_ID  \
# 0         269235387           42    105            1       20230603_0
# 1         262102261           43    113            1       20230118_1
# 2         267972239           43    106            1       20230509_2
# 3       263141402H1            0    101            2       20230206_3
# 4       269307857H1            0    101            2       20230604_4
# ...             ...          ...    ...          ...              ...
# 555112    278932501          105    361            3  20231212_555112
# 555113    274543137          105    344            3  20230916_555113
# 555114    272734727          105    112            3  20230810_555114
# 555115    270806588          105    126            3  20230704_555115
# 555116    263569764          105    341            3  20230212_555116
#
#         OFFENSE_ID  JURISDICTION_ID
# 0                1                1
# 1                2                1
# 2                3                1
# 3                4                1
# 4                4                1
# ...            ...              ...
# 555112          16                1
# 555113           6                1
# 555114          22                1
# 555115          20                1
# 555116          10                1
#
# [555117 rows x 7 columns]

# %%
#Push facts Dimension

facts_complaints_df.to_sql('FACTS_COMPLAINTS', con=engine, if_exists='append', index=False)
# Out:
# 117
